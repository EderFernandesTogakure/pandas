# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.0.5

# %%
#Abrir arquivo .csv parametros(arquivo.csv, separador , ou ; , codificação)
dataframe = pd.read_csv("alunos.csv", sep=";", encoding="ANSI")

# %%
dataframe.head()
# Out:
#       Nome  Idade Endereço           Cidade  Nota Aprovação Sexo
# 0    Renan     18   Rua 10         Maranhao     0       Não    M
# 1     João     19    Rua A   Rio de Janeiro    10       Sim    M
# 2   Maria      17    Rua 8       São Paulo      8      Sim     F
# 3  Junior      17    Rua 8       São Paulo      4       Não    M
# 4   Carlos     18   Rua 10  Belo Horizonte      9      Sim     M

# %%
dataframe
# Out:
#       Nome  Idade Endereço           Cidade  Nota Aprovação Sexo
# 0    Renan     18   Rua 10         Maranhao     0       Não    M
# 1     João     19    Rua A   Rio de Janeiro    10       Sim    M
# 2   Maria      17    Rua 8       São Paulo      8      Sim     F
# 3  Junior      17    Rua 8       São Paulo      4       Não    M
# 4   Carlos     18   Rua 10  Belo Horizonte      9      Sim     M
# 5  Robento     22   Rua 19  Santa Catarina      6      Sim     M
# 6   Carla      18   Rua 10         Maranhao    10      Sim     F
# 7   Renata     23   Rua 20         Curitiba     8      Sim     F

# %%
#Abrir arquivo .csv parametros(arquivo.csv, separador , ou ; , codificação, colunas)
dataframe = pd.read_csv("alunos.csv", sep=";", encoding="ANSI", usecols=["Nome","Idade","Aprovação","Nota"])

# %%
dataframe.head()
# Out:
#       Nome  Idade  Nota Aprovação
# 0    Renan     18     0       Não
# 1     João     19    10       Sim
# 2   Maria      17     8      Sim
# 3  Junior      17     4       Não
# 4   Carlos     18     9      Sim

# %%
dataframe.shape
# Out:
# (8, 4)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Nome       8 non-null      object
#  1   Idade      8 non-null      int64
#  2   Nota       8 non-null      int64
#  3   Aprovação  8 non-null      object
# dtypes: int64(2), object(2)
# memory usage: 384.0+ bytes

# %%
aluno = pd.read_csv("alunos.csv", sep=";", encoding="ANSI")

# %%
aluno
# Out:
#       Nome  Idade Endereço           Cidade  Nota Aprovação Sexo
# 0    Renan     18   Rua 10         Maranhao     0       Não    M
# 1     João     19    Rua A   Rio de Janeiro    10       Sim    M
# 2   Maria      17    Rua 8       São Paulo      8      Sim     F
# 3  Junior      17    Rua 8       São Paulo      4       Não    M
# 4   Carlos     18   Rua 10  Belo Horizonte      9      Sim     M
# 5  Robento     22   Rua 19  Santa Catarina      6      Sim     M
# 6   Carla      18   Rua 10         Maranhao    10      Sim     F
# 7   Renata     23   Rua 20         Curitiba     8      Sim     F

# %%
aluno.to_excel("alunos.xlsx")

# %%
dados = pd.read_excel("alunos.xlsx")

# %%
dados
# Out:
#    Unnamed: 0     Nome  Idade Endereço           Cidade  Nota Aprovação Sexo
# 0           0    Renan     18   Rua 10         Maranhao     0       Não    M
# 1           1     João     19    Rua A   Rio de Janeiro    10       Sim    M
# 2           2   Maria      17    Rua 8       São Paulo      8      Sim     F
# 3           3  Junior      17    Rua 8       São Paulo      4       Não    M
# 4           4   Carlos     18   Rua 10  Belo Horizonte      9      Sim     M
# 5           5  Robento     22   Rua 19  Santa Catarina      6      Sim     M
# 6           6   Carla      18   Rua 10         Maranhao    10      Sim     F
# 7           7   Renata     23   Rua 20         Curitiba     8      Sim     F

# %%
dados["Nome"]
# Out:
# 0      Renan
# 1       João
# 2     Maria
# 3    Junior
# 4     Carlos
# 5    Robento
# 6     Carla
# 7     Renata
# Name: Nome, dtype: object

# %%
dados[["Nome","Nota","Sexo"]]
# Out:
#       Nome  Nota Sexo
# 0    Renan     0    M
# 1     João    10    M
# 2   Maria      8    F
# 3  Junior      4    M
# 4   Carlos     9    M
# 5  Robento     6    M
# 6   Carla     10    F
# 7   Renata     8    F

# %%
dados.loc[[7]]
# Out:
#    Unnamed: 0    Nome  Idade Endereço    Cidade  Nota Aprovação Sexo
# 7           7  Renata     23   Rua 20  Curitiba     8      Sim     F

# %%
dados.loc[0:3]
# Out:
#    Unnamed: 0     Nome  Idade Endereço          Cidade  Nota Aprovação Sexo
# 0           0    Renan     18   Rua 10        Maranhao     0       Não    M
# 1           1     João     19    Rua A  Rio de Janeiro    10       Sim    M
# 2           2   Maria      17    Rua 8      São Paulo      8      Sim     F
# 3           3  Junior      17    Rua 8      São Paulo      4       Não    M

# %%
NovoData = {"Nome":["Tiago", "João", "Maria"],
            "Idade": ["18", "17", "21"]}

# %%
NovoData
# Out:
# {'Nome': ['Tiago', 'João', 'Maria'], 'Idade': ['18', '17', '21']}

# %%
nomes = pd.DataFrame(NovoData)

# %%
nomes
# Out:
#     Nome Idade
# 0  Tiago    18
# 1   João    17
# 2  Maria    21

# %%
nomes.to_excel("nome.xlsx")

# %%
dados.rename(columns={"Aprovação":"Aprovado"})
# Out:
#    Unnamed: 0     Nome  Idade Endereço           Cidade  Nota Aprovado Sexo
# 0           0    Renan     18   Rua 10         Maranhao     0      Não    M
# 1           1     João     19    Rua A   Rio de Janeiro    10      Sim    M
# 2           2   Maria      17    Rua 8       São Paulo      8     Sim     F
# 3           3  Junior      17    Rua 8       São Paulo      4      Não    M
# 4           4   Carlos     18   Rua 10  Belo Horizonte      9     Sim     M
# 5           5  Robento     22   Rua 19  Santa Catarina      6     Sim     M
# 6           6   Carla      18   Rua 10         Maranhao    10     Sim     F
# 7           7   Renata     23   Rua 20         Curitiba     8     Sim     F

# %%
dados
# Out:
#    Unnamed: 0     Nome  Idade Endereço           Cidade  Nota Aprovação Sexo
# 0           0    Renan     18   Rua 10         Maranhao     0       Não    M
# 1           1     João     19    Rua A   Rio de Janeiro    10       Sim    M
# 2           2   Maria      17    Rua 8       São Paulo      8      Sim     F
# 3           3  Junior      17    Rua 8       São Paulo      4       Não    M
# 4           4   Carlos     18   Rua 10  Belo Horizonte      9      Sim     M
# 5           5  Robento     22   Rua 19  Santa Catarina      6      Sim     M
# 6           6   Carla      18   Rua 10         Maranhao    10      Sim     F
# 7           7   Renata     23   Rua 20         Curitiba     8      Sim     F

# %%
dados.rename(columns={"Aprovação":"Aprovado"}, inplace = True)

# %%
dados
# Out:
#    Unnamed: 0     Nome  Idade Endereço           Cidade  Nota Aprovado Sexo
# 0           0    Renan     18   Rua 10         Maranhao     0      Não    M
# 1           1     João     19    Rua A   Rio de Janeiro    10      Sim    M
# 2           2   Maria      17    Rua 8       São Paulo      8     Sim     F
# 3           3  Junior      17    Rua 8       São Paulo      4      Não    M
# 4           4   Carlos     18   Rua 10  Belo Horizonte      9     Sim     M
# 5           5  Robento     22   Rua 19  Santa Catarina      6     Sim     M
# 6           6   Carla      18   Rua 10         Maranhao    10     Sim     F
# 7           7   Renata     23   Rua 20         Curitiba     8     Sim     F

# %%
dados
# Out:
#    Unnamed: 0     Nome  Idade Endereço           Cidade  Nota Aprovado Sexo
# 0           0    Renan     18   Rua 10         Maranhao     0      Não    M
# 1           1     João     19    Rua A   Rio de Janeiro    10      Sim    M
# 2           2   Maria      17    Rua 8       São Paulo      8     Sim     F
# 3           3  Junior      17    Rua 8       São Paulo      4      Não    M
# 4           4   Carlos     18   Rua 10  Belo Horizonte      9     Sim     M
# 5           5  Robento     22   Rua 19  Santa Catarina      6     Sim     M
# 6           6   Carla      18   Rua 10         Maranhao    10     Sim     F
# 7           7   Renata     23   Rua 20         Curitiba     8     Sim     F

# %%
dados.drop("Nome",axis = 1)
# Out:
#    Unnamed: 0  Idade Endereço           Cidade  Nota Aprovado Sexo
# 0           0     18   Rua 10         Maranhao     0      Não    M
# 1           1     19    Rua A   Rio de Janeiro    10      Sim    M
# 2           2     17    Rua 8       São Paulo      8     Sim     F
# 3           3     17    Rua 8       São Paulo      4      Não    M
# 4           4     18   Rua 10  Belo Horizonte      9     Sim     M
# 5           5     22   Rua 19  Santa Catarina      6     Sim     M
# 6           6     18   Rua 10         Maranhao    10     Sim     F
# 7           7     23   Rua 20         Curitiba     8     Sim     F

# %%
dados.drop(2)
# Out:
#    Unnamed: 0     Nome  Idade Endereço           Cidade  Nota Aprovado Sexo
# 0           0    Renan     18   Rua 10         Maranhao     0      Não    M
# 1           1     João     19    Rua A   Rio de Janeiro    10      Sim    M
# 3           3  Junior      17    Rua 8       São Paulo      4      Não    M
# 4           4   Carlos     18   Rua 10  Belo Horizonte      9     Sim     M
# 5           5  Robento     22   Rua 19  Santa Catarina      6     Sim     M
# 6           6   Carla      18   Rua 10         Maranhao    10     Sim     F
# 7           7   Renata     23   Rua 20         Curitiba     8     Sim     F

# %%
dados.drop([1,3,6])
# Out:
#    Unnamed: 0     Nome  Idade Endereço           Cidade  Nota Aprovado Sexo
# 0           0    Renan     18   Rua 10         Maranhao     0      Não    M
# 2           2   Maria      17    Rua 8       São Paulo      8     Sim     F
# 4           4   Carlos     18   Rua 10  Belo Horizonte      9     Sim     M
# 5           5  Robento     22   Rua 19  Santa Catarina      6     Sim     M
# 7           7   Renata     23   Rua 20         Curitiba     8     Sim     F
